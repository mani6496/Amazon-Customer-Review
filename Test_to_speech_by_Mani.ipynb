# %% [markdown]
# <a href="https://colab.research.google.com/github/mani6496/Amazon-Customer-Review/blob/main/Test_to_speech_by_Mani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cell 1 (Install gtts)
# !pip install gtts

# %%
'''# Cell 2 (Restart kernel - Manually interrupt and restart or run the command below)
import os
os._exit(00)'''
# Out:
# '# Cell 2 (Restart kernel - Manually interrupt and restart or run the command below)\nimport os\nos._exit(00)'

# %%
from gtts import gTTS
import IPython

# %%
def text_to_speech(text):
    speech = gTTS(text = text, lang = "en", slow = False)
    speech.save("output.mp3")
    return IPython.display.Audio("output.mp3", autoplay=True)

# %%
text = "hello Jimmi speaking now,I am a chatgpt bot and understand any human's language.I quick response any question and show answer with related question."

# %%
text_to_speech(text)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
